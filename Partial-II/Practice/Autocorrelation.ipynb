# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf

# %%
read_dir = r'C:\Users\ed_22\Documents\Selected-Statistics-Topics\Partial-II\Practice'
file_name = 'AirPassengers.csv'
read_path = os.path.join(read_dir, file_name)

# %%
data = pd.read_csv(read_path,
                   header=0,
                   names=['month', 'n_passengers'],
                  date_parser='month').set_index('month')
data.head()
# Out:
# C:\Users\ed_22\AppData\Local\Temp\ipykernel_11304\2459902261.py:1: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   data = pd.read_csv(read_path,
#          n_passengers
# month
# 1949-01           112
# 1949-02           118
# 1949-03           132
# 1949-04           129
# 1949-05           121

# %%
plot_acf(data)
plt.show()

# %%
plot_pacf(data)
plt.show()
